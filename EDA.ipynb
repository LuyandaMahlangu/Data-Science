# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#loading the data
data = pd.read_csv('iris.csv')
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# Checking for missing values
data.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
# Checking for duplicates 
data.duplicated().sum()
# Out:
# np.int64(3)

# %%
#Histograms for numerical columns
plt.figure(figsize=(10, 8))
data.drop('species', axis = 1).hist(bins=20)
plt.suptitle('Distribution of Sepal and Petal Measurements')
plt.tight_layout()
plt.show()

# %%
#Checking  for data types 
data.info
# Out:
# <bound method DataFrame.info of      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]>

# %%
# KDE Plots for better visualization 
plt.figure() 
sns.kdeplot(data['sepal_length'], shade=True, label='Sepal Length') 
sns.kdeplot(data['sepal_width'], shade=True, label='Sepal Width') 
sns.kdeplot(data['petal_length'], shade=True, label='Petal Length') 
sns.kdeplot(data['petal_width'], shade=True, label='Petal Width') 
plt.title('Kernel Density Estimation of Features') 
plt.legend() 
plt.show()
# Out:
# /var/folders/xh/30dn8wt502n89jfz9l3bk2xr0000gn/T/ipykernel_640/3757644669.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data['sepal_length'], shade=True, label='Sepal Length')
# /var/folders/xh/30dn8wt502n89jfz9l3bk2xr0000gn/T/ipykernel_640/3757644669.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data['sepal_width'], shade=True, label='Sepal Width')
# /var/folders/xh/30dn8wt502n89jfz9l3bk2xr0000gn/T/ipykernel_640/3757644669.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data['petal_length'], shade=True, label='Petal Length')
# ...

# %%
# pairplot to see relationshipbetween variables , grouped by species
sns.pairplot(data, hue = 'species')
plt.suptitle('Pairplot of Iris data', y = 1.02)
plt.show()

# %%
# Correlation heatmap
plt.figure(figsize=(8, 6))
corr= data.drop('species', axis=1).corr()
sns.heatmap(corr, annot = True, cmap = 'coolwarm', fmt = '.2f')
plt.title('Correlation heatmap of iris data')
plt.show()

# %%
# Group by species and calculate mean, min etc
grouped = data.groupby('species').agg(['mean', 'std', 'min', 'max'])
grouped
# Out:
#            sepal_length                     sepal_width                      \
#                    mean       std  min  max        mean       std  min  max
# species
# setosa            5.006  0.352490  4.3  5.8       3.418  0.381024  2.3  4.4
# versicolor        5.936  0.516171  4.9  7.0       2.770  0.313798  2.0  3.4
# virginica         6.588  0.635880  4.9  7.9       2.974  0.322497  2.2  3.8
#
#            petal_length                     petal_width
#                    mean       std  min  max        mean       std  min  max
# species
# setosa            1.464  0.173511  1.0  1.9       0.244  0.107210  0.1  0.6
# versicolor        4.260  0.469911  3.0  5.1       1.326  0.197753  1.0  1.8
# virginica         5.552  0.551895  4.5  6.9       2.026  0.274650  1.4  2.5
